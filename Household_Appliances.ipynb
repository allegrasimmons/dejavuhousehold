# %% [markdown]
# # FINGERPRINTING AND FILE RECONGIZING HOUSEHOLD APPLIANCES

# %% [markdown]
# ## Installing all packpages and linking to database

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#connecting to database

from dejavu import Dejavu

config = {
    "database_type": "mysql",
    "database": {
        "host": "127.0.0.1",
        "user": "root",
        "password": "CookieYumYum", 
        "database": "dejavu",
    }
}

djv = Dejavu(config)

# %% [markdown]
# # Fingerprinting HouseHold Directory

# %%
djv.fingerprint_directory("/Users/allegrasimmons/Downloads/Dining_Room_Audios", [".wav"], 3)
# Out:
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Washer/fromdiningroom-washer1.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Dishwasher/no ac/dishwasherfromdiningroomnoac2.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Dishwasher/no ac/dishwasherfromdiningroomnoac1.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Fridge/fromdinningroom-openingfridgedoor4.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Fridge/fromdinningroom-openingfridgedoor20.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Fridge/fromdinningroom-openingfridgedoor21.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Dining_Room_Audios/Fridge/fromdinningroom-openingfridgedoor5.wav already fingerprinted, continuing...
# ...

# %%
djv.fingerprint_directory("/Users/allegrasimmons/Downloads/Living_Room_Audios", [".wav"], 3)
# Out:
# /Users/allegrasimmons/Downloads/Living_Room_Audios/washer/fromlivingroom-washer1.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/ac/livingroom-dishwasherwithac1.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/ac/livingroom-dishwasherwithac2.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/ac/livingroom-dishwasherwithac.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/w-ac/dishwasherfromlivingroom(noac).wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/w-ac/dishwasherfromlivingroom(noac)2.wav already fingerprinted, continuing...
# /Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/w-ac/dishwasherfromlivingroom(noac)1.wav already fingerprinted, continuing...

# %%
#nowtryingtorecongizenotfingerprintedaudios

from dejavu.logic.recognizer.file_recognizer import FileRecognizer
recognizer = FileRecognizer(djv)

# %% [markdown]
# ## Dishwasher Dining Room

# %%
dinningroomdishwasher_audio = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Dining_Room_Audios/Dishwasher/no ac/dishwasherfromdiningroomnoac1.wav")

# %%
data = {'Result 1': 1.0, 'Result 2': 0.17}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Dining Room')

plt.show()

# %%
dinningroomdishwasher_audio2 = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Dining_Room_Audios/Dishwasher/no ac/dishwasherfromdiningroomnoac2.wav")
dinningroomdishwasher_audio2
# Out:
# {'total_time': 0.42650389671325684,
#  'fingerprint_time': 0.3577439785003662,
#  'query_time': 0.05095505714416504,
#  'align_time': 0.016635894775390625,
#  'results': [{'song_id': 228,
#    'song_name': b'dishwasherfromdiningroomnoac2',
#    'input_total_hashes': 436,
#    'fingerprinted_hashes_in_db': 436,
#    'hashes_matched_in_input': 436,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'91B06E3A07982A028184EFC68190E46FBAFB0F65'},
#   {'song_id': 112,
#    'song_name': b'nathaniel-walkingbarefootinhallway',
#    'input_total_hashes': 436,
#    'fingerprinted_hashes_in_db': 882,
#    'hashes_matched_in_input': 455,
#    'input_confidence': 1.04,
#    'fingerprinted_confidence': 0.52,
#    'offset': 1723,
#    'offset_seconds': 80.01596,
#    'file_sha1': b'A3B0C0763B86D6107F0733A115B091FCDA477CEF'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 0.52}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Dining Room')

plt.show()

# %%
diningroomfrontdoor_confidence = [
    {'Audio': 'Dishwasher 2', 'First Result': '1', 'Second Result': '0.17'},
    {'Audio': 'Dishwasher 1', 'First Result': '1', 'Second Result': '0.52'}
]

diningroomfrontdoor_confidence = pd.DataFrame(diningroomfrontdoor_confidence)

# Convert the confidence columns to numeric
diningroomfrontdoor_confidence['First Result'] = pd.to_numeric(diningroomfrontdoor_confidence['First Result'])
diningroomfrontdoor_confidence['Second Result'] = pd.to_numeric(diningroomfrontdoor_confidence['Second Result'])

# Set the 'Audio' column as the index
diningroomfrontdoor_confidence.set_index('Audio', inplace=True)

# Create a bar chart
ax = diningroomfrontdoor_confidence.plot(kind='bar')
ax.set_ylabel('Confidence')
ax.set_title('Confidence Comparison for Different Audio Dishwasher (Dining Room)')

# Adding confidence values above the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()

plt.ylim(0, 1.2)

# Display the bar chart
plt.show()

# %% [markdown]
# ## Dishwasher Living Room

# %%
livingroomdishwasher_audio = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/w-ac/dishwasherfromlivingroom(noac).wav")
livingroomdishwasher_audio
# Out:
# {'total_time': 0.49247097969055176,
#  'fingerprint_time': 0.40466928482055664,
#  'query_time': 0.06911897659301758,
#  'align_time': 0.018379926681518555,
#  'results': [{'song_id': 256,
#    'song_name': b'dishwasherfromlivingroom(noac)',
#    'input_total_hashes': 735,
#    'fingerprinted_hashes_in_db': 735,
#    'hashes_matched_in_input': 735,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'9CC898E9D64F779E9700C4D889752C5AB039B963'},
#   {'song_id': 259,
#    'song_name': b'dishwasherfromlivingroom(noac)1',
#    'input_total_hashes': 735,
#    'fingerprinted_hashes_in_db': 735,
#    'hashes_matched_in_input': 735,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'9CC898E9D64F779E9700C4D889752C5AB039B963'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 1}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Living Room')

plt.show()

# %%
livingroomdishwasher_audio2 = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/w-ac/dishwasherfromlivingroom(noac)1.wav")
livingroomdishwasher_audio2
# Out:
# {'total_time': 0.48559999465942383,
#  'fingerprint_time': 0.42832088470458984,
#  'query_time': 0.03968405723571777,
#  'align_time': 0.017306804656982422,
#  'results': [{'song_id': 256,
#    'song_name': b'dishwasherfromlivingroom(noac)',
#    'input_total_hashes': 735,
#    'fingerprinted_hashes_in_db': 735,
#    'hashes_matched_in_input': 735,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'9CC898E9D64F779E9700C4D889752C5AB039B963'},
#   {'song_id': 259,
#    'song_name': b'dishwasherfromlivingroom(noac)1',
#    'input_total_hashes': 735,
#    'fingerprinted_hashes_in_db': 735,
#    'hashes_matched_in_input': 735,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'9CC898E9D64F779E9700C4D889752C5AB039B963'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 1}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Living Room')

plt.show()

# %%
livingroomdishwasher_audio3 = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/w-ac/dishwasherfromlivingroom(noac)2.wav")
livingroomdishwasher_audio3
# Out:
# {'total_time': 0.4185500144958496,
#  'fingerprint_time': 0.3325779438018799,
#  'query_time': 0.0691382884979248,
#  'align_time': 0.016333818435668945,
#  'results': [{'song_id': 257,
#    'song_name': b'dishwasherfromlivingroom(noac)2',
#    'input_total_hashes': 601,
#    'fingerprinted_hashes_in_db': 601,
#    'hashes_matched_in_input': 601,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'094C47FF77CC8C476F158415C4FA81106D5D4A46'},
#   {'song_id': 206,
#    'song_name': b'fromlivingroom-openingslidingglassdoor11',
#    'input_total_hashes': 601,
#    'fingerprinted_hashes_in_db': 115,
#    'hashes_matched_in_input': 16,
#    'input_confidence': 0.03,
#    'fingerprinted_confidence': 0.14,
#    'offset': -952,
#    'offset_seconds': -44.21079,
#    'file_sha1': b'3477FA07C4DAFD72E592E9788C23E57E1750D261'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 0.14}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Living Room')

plt.show()

# %%
diningroomfrontdoor_confidence = [
    {'Audio': 'Dishwasher - Living Room', 'First Result': '1', 'Second Result': '0.14'},
    {'Audio': 'Dishwasher - Living Room', 'First Result': '1', 'Second Result': '1'},
    {'Audio': 'Dishwasher - Living Room', 'First Result': '1', 'Second Result': '1'}
]

diningroomfrontdoor_confidence = pd.DataFrame(diningroomfrontdoor_confidence)

# Convert the confidence columns to numeric
diningroomfrontdoor_confidence['First Result'] = pd.to_numeric(diningroomfrontdoor_confidence['First Result'])
diningroomfrontdoor_confidence['Second Result'] = pd.to_numeric(diningroomfrontdoor_confidence['Second Result'])

# Set the 'Audio' column as the index
diningroomfrontdoor_confidence.set_index('Audio', inplace=True)

# Create a bar chart
ax = diningroomfrontdoor_confidence.plot(kind='bar')
ax.set_ylabel('Confidence')
ax.set_title('Confidence Comparison for Different Audio Dishwasher (Living Room)')

# Adding confidence values above the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()

plt.ylim(0, 1.6)

# Display the bar chart
plt.show()

# %% [markdown]
# ## Dishwasher Living Room with AC

# %%
livingroomdishwasherac_audio = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/ac/livingroom-dishwasherwithac.wav")
livingroomdishwasherac_audio
# Out:
# {'total_time': 0.808772087097168,
#  'fingerprint_time': 0.7096002101898193,
#  'query_time': 0.0741419792175293,
#  'align_time': 0.024372100830078125,
#  'results': [{'song_id': 258,
#    'song_name': b'livingroom-dishwasherwithac',
#    'input_total_hashes': 2489,
#    'fingerprinted_hashes_in_db': 2489,
#    'hashes_matched_in_input': 2489,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'2D92B612C10E0A4C2013DC82CFAD5A7132D853F7'},
#   {'song_id': 255,
#    'song_name': b'livingroom-dishwasherwithac1',
#    'input_total_hashes': 2489,
#    'fingerprinted_hashes_in_db': 1560,
#    'hashes_matched_in_input': 1560,
#    'input_confidence': 0.63,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'3DA806B3640024C8025FDEBADF53050699A3B8B2'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 1.0}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Living Room with AC')

plt.show()

# %%
livingroomdishwasherac_audio2 = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/ac/livingroom-dishwasherwithac1.wav")
livingroomdishwasherac_audio2
# Out:
# {'total_time': 0.4366600513458252,
#  'fingerprint_time': 0.3707449436187744,
#  'query_time': 0.04489421844482422,
#  'align_time': 0.02058124542236328,
#  'results': [{'song_id': 255,
#    'song_name': b'livingroom-dishwasherwithac1',
#    'input_total_hashes': 1560,
#    'fingerprinted_hashes_in_db': 1560,
#    'hashes_matched_in_input': 1560,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'3DA806B3640024C8025FDEBADF53050699A3B8B2'},
#   {'song_id': 258,
#    'song_name': b'livingroom-dishwasherwithac',
#    'input_total_hashes': 1560,
#    'fingerprinted_hashes_in_db': 2489,
#    'hashes_matched_in_input': 1823,
#    'input_confidence': 1.17,
#    'fingerprinted_confidence': 0.73,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'2D92B612C10E0A4C2013DC82CFAD5A7132D853F7'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 0.73}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Living Room With AC')

plt.show()

# %%
livingroomdishwasherac_audio3 = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Downloads/Living_Room_Audios/Dishwasher/ac/livingroom-dishwasherwithac2.wav")

# %%
data = {'Result 1': 1.0, 'Result 2': 0.27}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Dishwasher - Living Room with AC')

plt.show()

# %%
diningroomfrontdoor_confidence = [
    {'Audio': 'Dishwasher - Living Room with AC 1', 'First Result': '1', 'Second Result': '0.27'},
    {'Audio': 'Dishwasher - Living Room with AC 2', 'First Result': '1', 'Second Result': '0.73'},
    {'Audio': 'Dishwasher - Living Room with AC 3', 'First Result': '1', 'Second Result': '1'},
]

diningroomfrontdoor_confidence = pd.DataFrame(diningroomfrontdoor_confidence)

# Convert the confidence columns to numeric
diningroomfrontdoor_confidence['First Result'] = pd.to_numeric(diningroomfrontdoor_confidence['First Result'])
diningroomfrontdoor_confidence['Second Result'] = pd.to_numeric(diningroomfrontdoor_confidence['Second Result'])

# Set the 'Audio' column as the index
diningroomfrontdoor_confidence.set_index('Audio', inplace=True)

# Create a bar chart
ax = diningroomfrontdoor_confidence.plot(kind='bar')
ax.set_ylabel('Confidence')
ax.set_title('Confidence Comparison for Different Audio Dishwasher (Dining Room)')

# Adding confidence values above the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()

plt.ylim(0, 1.8)

# Display the bar chart
plt.show()

# %%
dinningroomslidingglassdoor = [
    {'Audio': 'Dishwasher - Living Room with AC 1', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room with AC 2', 'First': 'yes', 'Second': 'yes'}, 
    {'Audio': 'Dishwasher - Living Room with AC', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dishwasher - Living Room with AC', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dishwasher - Living Room 1', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room 2', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Dining Room 2', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dishwasher - Dining Room', 'First': 'yes', 'Second': 'no'},
]

dinningroomslidingglassdoor = pd.DataFrame(dinningroomslidingglassdoor)

# Calculate the matching percentage
matching_percentage = (dinningroomslidingglassdoor['First'] == 'yes').sum() / len(dinningroomslidingglassdoor) * 100
mismatching_percentage = 100 - matching_percentage

# Create a bar chart for matching percentages
categories = ['Matching (Yes)', 'Mismatching (No)']
percentages = [matching_percentage, mismatching_percentage]
colors = ['lightgreen', 'lightcoral']

plt.figure(figsize=(8, 6))
plt.bar(categories, percentages, color=colors)
plt.ylabel('Percentage')
plt.title('Matching Percentages for Dishwasher from Dining and Living Room (First Result)')

# Add labels to the bars
for i, percentage in enumerate(percentages):
    plt.annotate(f'{percentage:.1f}%', (i, percentage), ha='center', va='bottom')

plt.ylim(0, 110)  # Set the y-axis limit from 0% to 100%

plt.show()

# %%
dinningroomslidingglassdoor = [
    {'Audio': 'Dishwasher - Living Room with AC 1', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room with AC 2', 'First': 'yes', 'Second': 'yes'}, 
    {'Audio': 'Dishwasher - Living Room with AC', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dishwasher - Living Room with AC', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dishwasher - Living Room 1', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room 2', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Living Room', 'First': 'yes', 'Second': 'yes'},
    {'Audio': 'Dishwasher - Dining Room 2', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dishwasher - Dining Room', 'First': 'yes', 'Second': 'no'},
]

dinningroomslidingglassdoor = pd.DataFrame(dinningroomslidingglassdoor)

# Calculate the matching percentage
matching_percentage = (dinningroomslidingglassdoor['Second'] == 'yes').sum() / len(dinningroomslidingglassdoor) * 100
mismatching_percentage = 100 - matching_percentage

# Create a bar chart for matching percentages
categories = ['Matching (Yes)', 'Mismatching (No)']
percentages = [matching_percentage, mismatching_percentage]
colors = ['lightgreen', 'lightcoral']

plt.figure(figsize=(8, 6))
plt.bar(categories, percentages, color=colors)
plt.ylabel('Percentage')
plt.title('Matching Percentages for Dishwasher from Dining and Living Room (First Result)')

# Add labels to the bars
for i, percentage in enumerate(percentages):
    plt.annotate(f'{percentage:.1f}%', (i, percentage), ha='center', va='bottom')

plt.ylim(0, 110)  # Set the y-axis limit from 0% to 100%

plt.show()

# %% [markdown]
# ## Washer from Dining Room

# %%
diningroom_washer = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Desktop/Household_sounds/Household_Appliances/Dining_Room_Audios/Washer/fromdiningroom-washer1.wav")
diningroom_washer
# Out:
# {'total_time': 0.5452659130096436,
#  'fingerprint_time': 0.37550973892211914,
#  'query_time': 0.15113210678100586,
#  'align_time': 0.018122196197509766,
#  'results': [{'song_id': 231,
#    'song_name': b'fromdiningroom-washer1',
#    'input_total_hashes': 991,
#    'fingerprinted_hashes_in_db': 991,
#    'hashes_matched_in_input': 991,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'F62865F9C8F21FC60A58AC88FC66E1FD66C8E435'},
#   {'song_id': 255,
#    'song_name': b'livingroom-dishwasherwithac1',
#    'input_total_hashes': 991,
#    'fingerprinted_hashes_in_db': 1560,
#    'hashes_matched_in_input': 203,
#    'input_confidence': 0.2,
#    'fingerprinted_confidence': 0.13,
#    'offset': 407,
#    'offset_seconds': 18.90104,
#    'file_sha1': b'3DA806B3640024C8025FDEBADF53050699A3B8B2'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 0.13}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Washer - Dining Room')

plt.show()

# %% [markdown]
# ## Washer from Living Room

# %%
diningroom_washer = djv.recognize(FileRecognizer, "/Users/allegrasimmons/Desktop/Household_sounds/Household_Appliances/Living_Room_Audios/washer/fromlivingroom-washer1.wav")
diningroom_washer
# Out:
# {'total_time': 0.5010449886322021,
#  'fingerprint_time': 0.32383012771606445,
#  'query_time': 0.15829205513000488,
#  'align_time': 0.018445968627929688,
#  'results': [{'song_id': 254,
#    'song_name': b'fromlivingroom-washer1',
#    'input_total_hashes': 1666,
#    'fingerprinted_hashes_in_db': 1666,
#    'hashes_matched_in_input': 1666,
#    'input_confidence': 1.0,
#    'fingerprinted_confidence': 1.0,
#    'offset': 0,
#    'offset_seconds': 0.0,
#    'file_sha1': b'8186EB448C220910AAD0F0266BA3D9AB65B226E4'},
#   {'song_id': 93,
#    'song_name': b'15-nathaniel-walkingbarefootinhallway',
#    'input_total_hashes': 1666,
#    'fingerprinted_hashes_in_db': 30,
#    'hashes_matched_in_input': 17,
#    'input_confidence': 0.01,
#    'fingerprinted_confidence': 0.57,
#    'offset': -609,
#    'offset_seconds': -28.2819,
#    'file_sha1': b'D563E9FD913303F7E52FD0D750E4AADC2F3A7A43'}]}

# %%
data = {'Result 1': 1.0, 'Result 2': 0.57}
songs = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)

bars = plt.bar(songs, values, color='red', width=0.4, edgecolor='black')

# Adding result numbers to sit right on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value), ha='center', va='bottom')

plt.xlabel('Results')
plt.ylabel('Confidence')
plt.title('Confidence Comparison for Washer - Living Room')

plt.show()

# %%
diningroomfrontdoor_confidence = [
    {'Audio': 'Washer - Dining Room 1', 'First Result': '1', 'Second Result': '0.13'},
    {'Audio': 'Washer - Living Room', 'First Result': '1', 'Second Result': '0.57'}
]

diningroomfrontdoor_confidence = pd.DataFrame(diningroomfrontdoor_confidence)

# Convert the confidence columns to numeric
diningroomfrontdoor_confidence['First Result'] = pd.to_numeric(diningroomfrontdoor_confidence['First Result'])
diningroomfrontdoor_confidence['Second Result'] = pd.to_numeric(diningroomfrontdoor_confidence['Second Result'])

# Set the 'Audio' column as the index
diningroomfrontdoor_confidence.set_index('Audio', inplace=True)

# Create a bar chart
ax = diningroomfrontdoor_confidence.plot(kind='bar')
ax.set_ylabel('Confidence')
ax.set_title('Confidence Comparison for Different Audio Dishwasher (Dining and Living Room)')

# Adding confidence values above the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()

plt.ylim(0, 1.4)

# Display the bar chart
plt.show()

# %%
dinningroomslidingglassdoor = [
    {'Audio': 'Living Room Washer 1', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dining Room Washer 1', 'First': 'yes', 'Second': 'no'}
]

dinningroomslidingglassdoor = pd.DataFrame(dinningroomslidingglassdoor)
print(dinningroomslidingglassdoor)
# Out:
#                   Audio First Second
# 0  Living Room Washer 1   yes     no
# 1  Dining Room Washer 1   yes     no

# %%
dinningroomslidingglassdoor = [
    {'Audio': 'Living Room Washer 1', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dining Room Washer 1', 'First': 'yes', 'Second': 'no'}
]

dinningroomslidingglassdoor = pd.DataFrame(dinningroomslidingglassdoor)

# Calculate the matching percentage
matching_percentage = (dinningroomslidingglassdoor['First'] == 'yes').sum() / len(dinningroomslidingglassdoor) * 100
mismatching_percentage = 100 - matching_percentage

# Create a bar chart for matching percentages
categories = ['Matching (Yes)', 'Mismatching (No)']
percentages = [matching_percentage, mismatching_percentage]
colors = ['lightgreen', 'lightcoral']

plt.figure(figsize=(8, 6))
plt.bar(categories, percentages, color=colors)
plt.ylabel('Percentage')
plt.title('Matching Percentages for Washer from Dining and Living Room (First Result)')

# Add labels to the bars
for i, percentage in enumerate(percentages):
    plt.annotate(f'{percentage:.1f}%', (i, percentage), ha='center', va='bottom')

plt.ylim(0, 110)  # Set the y-axis limit from 0% to 100%

plt.show()

# %%
dinningroomslidingglassdoor = [
    {'Audio': 'Living Room Washer 1', 'First': 'yes', 'Second': 'no'},
    {'Audio': 'Dining Room Washer 1', 'First': 'yes', 'Second': 'no'}
]

dinningroomslidingglassdoor = pd.DataFrame(dinningroomslidingglassdoor)

# Calculate the matching percentage
matching_percentage = (dinningroomslidingglassdoor['Second'] == 'yes').sum() / len(dinningroomslidingglassdoor) * 100
mismatching_percentage = 100 - matching_percentage

# Create a bar chart for matching percentages
categories = ['Matching (Yes)', 'Mismatching (No)']
percentages = [matching_percentage, mismatching_percentage]
colors = ['lightgreen', 'lightcoral']

plt.figure(figsize=(8, 6))
plt.bar(categories, percentages, color=colors)
plt.ylabel('Percentage')
plt.title('Matching Percentages for Washer from Dining and Living Room (Second Result)')

# Add labels to the bars
for i, percentage in enumerate(percentages):
    plt.annotate(f'{percentage:.1f}%', (i, percentage), ha='center', va='bottom')

plt.ylim(0, 110)  # Set the y-axis limit from 0% to 100%

plt.show()
